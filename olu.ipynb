# %%
from feature_extractor import FeatureExtractor
from normalizer import Normalizer
from reader import PSBDataset
from helper.config import FEATURE_DATA_FILE, DEBUG, DATA_PATH_NORMED_SUBSET, DATA_PATH_NORMED, CLASS_FILE, DATA_PATH_PSB, DATA_PATH_DEBUG
import time
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt

# %%
dataset = PSBDataset(DATA_PATH_NORMED, class_file_path=CLASS_FILE)
dataset.read()
dataset.show_class_histogram()

# %%
pd_data = pd.DataFrame(dataset.data_descriptors)
counts_list = list(Counter(pd_data["label"].astype(str).values).items())
counts = pd.DataFrame([{"label": label, "counts": int(count)} for label, count in counts_list])
fig = plt.figure(figsize=(15, 5))
ax = fig.add_subplot()
ax.tick_params(axis='x', rotation=90)
ax.bar(counts["label"], counts["counts"])
fig.tight_layout()
fig.savefig('lbl.png')

# %%
pd_data = pd.DataFrame(dataset.data_descriptors)
counts_list = list(Counter(pd_data["label"].astype(str).values).items())
counts = pd.DataFrame([{"label": label, "counts": int(count)} for label, count in counts_list])
fig = plt.figure(figsize=(15, 15))
ax = fig.add_subplot()
ax.tick_params(rotation=50)
ax.pie(counts["counts"], labels=counts["label"], )
ax.axis('equal') 
fig.tight_layout()
fig.savefig('lbl.png')

# %%
counts
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/anaconda3/envs/mmr/lib/python3.8/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2890             try:
# -> 2891                 return self._engine.get_loc(casted_key)
#    2892             except KeyError as err:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'fighter_jet'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-51-355440bc9bb4> in <module>
# ...
